# %%
#Santander Customer Satisfaction

#from google.colab import drive
#drive.mount('/content/drive/')

from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
#Import Python Packages
#Import sckikit for ML

import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report

# %%
#Read training data file
trainfile = r'/gdrive/My Drive/CIS508/1/train.csv'
trainData = pd.read_csv(trainfile)

#Read test data file
testfile = r'/gdrive/My Drive/CIS508/1/test.csv'
testData = pd.read_csv(testfile)

trainData.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult3          var38  TARGET
# 0   1     2     23  ...                     0.0   39205.170000       0
# 1   3     2     34  ...                     0.0   49278.030000       0
# 2   4     2     23  ...                     0.0   67333.770000       0
# 3   8     2     37  ...                     0.0   64007.970000       0
# 4  10     2     39  ...                     0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %%
testData.head()
# Out:
#    ID  var3  var15  ...  saldo_medio_var44_ult1  saldo_medio_var44_ult3      var38
# 0   2     2     32  ...                     0.0                     0.0   40532.10
# 1   5     2     35  ...                     0.0                     0.0   45486.72
# 2   6     2     23  ...                     0.0                     0.0   46993.95
# 3   7     2     24  ...                     0.0                     0.0  187898.61
# 4   9     2     23  ...                     0.0                     0.0   73649.73
#
# [5 rows x 370 columns]

# %%
#show datatypes and data shapes
print(trainData.shape)
print(trainData.dtypes)
# Out:
# (76020, 371)
# ID                           int64
# var3                         int64
# var15                        int64
# imp_ent_var16_ult1         float64
# imp_op_var39_comer_ult1    float64
#                             ...
# saldo_medio_var44_hace3    float64
# saldo_medio_var44_ult1     float64
# saldo_medio_var44_ult3     float64
# var38                      float64
# TARGET                       int64
# Length: 371, dtype: object

# %%
#Copy Train data excluding target
X_Train = trainData.iloc[:, :-1].copy() #X_train
X_Test = testData.iloc[:, :].copy() #X_test

# %%
#Select just Target Column
Y_Train = trainData.iloc[:, -1]

# %%
#Create Decision Tree Classifier WITHOUT any paramets - MODEL 0
clf=DecisionTreeClassifier()

#Apply Classifier on Train and Target
clf.fit(X_Train,Y_Train)

#Getting Class Prediction as a data frame
pred=pd.DataFrame(clf.predict(X_Train),columns=["Target"])

#Print Classification Report - MODEL 0
print(classification_report(Y_Train,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     73012
#            1       1.00      1.00      1.00      3008
#
#     accuracy                           1.00     76020
#    macro avg       1.00      1.00      1.00     76020
# weighted avg       1.00      1.00      1.00     76020

# %%
#Write into a file with actual prediction for the corresponding IDs
export = pd.concat([X_Test['ID'], pred.reindex(X_Test['ID'].index)], axis=1)
export.head()
export.to_csv("/gdrive/My Drive/CIS508/1/prediction_results0.csv", index = None)

# %%
#Create Decision Tree Classifier WITH PARAMETERS - MODEL 1
clf=DecisionTreeClassifier(max_depth=15)
clf.fit(X_Train,Y_Train)
pred1=pd.DataFrame(clf.predict(X_Train),columns=["Target"])
print(classification_report(Y_Train,pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     73012
#            1       0.94      0.20      0.33      3008
#
#     accuracy                           0.97     76020
#    macro avg       0.96      0.60      0.65     76020
# weighted avg       0.97      0.97      0.96     76020

# %%
#Write into a file with actual prediction for the corresponding IDs
export = pd.concat([X_Test['ID'], pred1.reindex(X_Test['ID'].index)], axis=1)
export.head()
export.to_csv("/gdrive/My Drive/CIS508/1/prediction_results11.csv", index = None)

# %%
#Create Decision Tree Classifier WITH PARAMETERS - MODEL 2
clf=DecisionTreeClassifier(criterion='gini', min_samples_leaf=10, max_depth=50)
clf.fit(X_Train,Y_Train)
pred2=pd.DataFrame(clf.predict(X_Train),columns=["Target"])
print(classification_report(Y_Train,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98     73012
#            1       0.62      0.15      0.24      3008
#
#     accuracy                           0.96     76020
#    macro avg       0.79      0.57      0.61     76020
# weighted avg       0.95      0.96      0.95     76020

# %%
#Write into a file with actual prediction for the corresponding IDs
export = pd.concat([X_Test['ID'], pred3.reindex(X_Test['ID'].index)], axis=1)
export.head()
export.to_csv("/gdrive/My Drive/CIS508/1/prediction_results2.csv", index = None)

# %%
#Create Decision Tree Classifier WITH PARAMETERS - MODEL 3
clf=DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=70, max_depth=100)
clf.fit(X_Train,Y_Train)
pred3=pd.DataFrame(clf.predict(X_Train),columns=["Target"])
print(classification_report(Y_Train,pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     73012
#            1       0.69      0.02      0.03      3008
#
#     accuracy                           0.96     76020
#    macro avg       0.83      0.51      0.51     76020
# weighted avg       0.95      0.96      0.94     76020

# %%
#Write into a file with actual prediction for the corresponding IDs
export = pd.concat([X_Test['ID'], pred3.reindex(X_Test['ID'].index)], axis=1)
export.head()
export.to_csv("/gdrive/My Drive/CIS508/1/prediction_results3.csv", index = None)
